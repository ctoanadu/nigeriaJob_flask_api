# %%
from web_scrapper import create_dict
import pandas as pd 
import pandasql as ps

df = pd.DataFrame(create_dict())
len(df)
# Out:
# 46

# %%
df.head(5)
# Out:
#                                             url_link
# 0  https://www.nigeriajob.com/job-vacancies-niger...  \
# 1  https://www.nigeriajob.com/job-vacancies-niger...
# 2  https://www.nigeriajob.com/job-vacancies-niger...
# 3  https://www.nigeriajob.com/job-vacancies-niger...
# 4  https://www.nigeriajob.com/job-vacancies-niger...
#
#                      job_title company_name
# 0     Examinations Invigilator       VICTVS  \
# 1  Developer ServiceNow (ITSM)  AFRICASHORE
# 2      ANGULAR Developer (M/F)  AFRICASHORE
# 3        DevOps Engineer (M/F)  AFRICASHORE
# 4       DOTNET Developer (M/F)  AFRICASHORE
#
#                                      job_description
# 0  Job descriptionVICTVS In-Centre Exam Invigilat...  \
# 1  \n\t  We are looking for Developer ServiceNow ...
# 2  We are looking for ANGULAR Developer profiles ...
# 3  We are looking for DevOps Engineer profiles / ...
# 4  We are looking for DOTNET Developer profiles /...
#
#                                             location date_posted
# 0                                            [Lagos]  2023-04-21  \
# 1  [Abeokuta, Ogun, Abia, Abuja, Adamawa, Akwa, I...  2023-04-21
# 2  [Abeokuta, Ogun, Abia, Abuja, Adamawa, Akwa, I...  2023-04-21
# 3  [Abeokuta, Ogun, Abia, Abuja, Adamawa, Akwa, I...  2023-04-21
# 4  [Abeokuta, Ogun, Abia, Abuja, Adamawa, Akwa, I...  2023-04-21
#
#                                         technologies
# 0  [ACCESS, ASSISTANTSHIP, DELIVERY, MONITORING, ...
# 1  [AGILE, AJAX, BOOTSTRAP, CSS, DELTA, EDGE, GEM...
# 2  [BOOTSTRAP, CSS3, CVS, DELTA, GIT, JAVASCRIPT,...
# 3  [ARTIFACTORY, AZURE, CVS, DELTA, DOCKER, DYNAT...
# 4  [API, ASP, C#, CSS, CVS, DELTA, DOTNET, FRONT ...

# %%
import  pandasql as ps 
df  
# Create a dataframe for technologies
df_technologies = df.explode('technologies').reset_index(drop=True)
df_technologies
# Out:
#                                               url_link
# 0    https://www.nigeriajob.com/job-vacancies-niger...  \
# 1    https://www.nigeriajob.com/job-vacancies-niger...
# 2    https://www.nigeriajob.com/job-vacancies-niger...
# 3    https://www.nigeriajob.com/job-vacancies-niger...
# 4    https://www.nigeriajob.com/job-vacancies-niger...
# ..                                                 ...
# 501  https://www.nigeriajob.com/job-vacancies-niger...
# 502  https://www.nigeriajob.com/job-vacancies-niger...
# 503  https://www.nigeriajob.com/job-vacancies-niger...
# 504  https://www.nigeriajob.com/job-vacancies-niger...
# 505  https://www.nigeriajob.com/job-vacancies-niger...
#
#                                 job_title company_name
# 0                Examinations Invigilator       VICTVS  \
# 1                Examinations Invigilator       VICTVS
# 2                Examinations Invigilator       VICTVS
# 3                Examinations Invigilator       VICTVS
# 4                Examinations Invigilator       VICTVS
# ..                                    ...          ...
# 501  Data Science Specialist- BMGF (HCD+)          DAI
# 502  Data Science Specialist- BMGF (HCD+)          DAI
# 503  Data Science Specialist- BMGF (HCD+)          DAI
# 504  Data Science Specialist- BMGF (HCD+)          DAI
# 505  Data Science Specialist- BMGF (HCD+)          DAI
#
#                                        job_description
# 0    Job descriptionVICTVS In-Centre Exam Invigilat...  \
# 1    Job descriptionVICTVS In-Centre Exam Invigilat...
# 2    Job descriptionVICTVS In-Centre Exam Invigilat...
# 3    Job descriptionVICTVS In-Centre Exam Invigilat...
# 4    Job descriptionVICTVS In-Centre Exam Invigilat...
# ..                                                 ...
# 501  Background of the projectAfrica (HCD+) is a pl...
# 502  Background of the projectAfrica (HCD+) is a pl...
# 503  Background of the projectAfrica (HCD+) is a pl...
# 504  Background of the projectAfrica (HCD+) is a pl...
# 505  Background of the projectAfrica (HCD+) is a pl...
#
#                                               location date_posted
# 0                                              [Lagos]  2023-04-21  \
# 1                                              [Lagos]  2023-04-21
# 2                                              [Lagos]  2023-04-21
# 3                                              [Lagos]  2023-04-21
# 4                                              [Lagos]  2023-04-21
# ..                                                 ...         ...
# 501  [Abeokuta, Ogun, Abia, Abuja, Adamawa, Akwa, I...  2023-03-02
# 502  [Abeokuta, Ogun, Abia, Abuja, Adamawa, Akwa, I...  2023-03-02
# 503  [Abeokuta, Ogun, Abia, Abuja, Adamawa, Akwa, I...  2023-03-02
# 504  [Abeokuta, Ogun, Abia, Abuja, Adamawa, Akwa, I...  2023-03-02
# 505  [Abeokuta, Ogun, Abia, Abuja, Adamawa, Akwa, I...  2023-03-02
#
#       technologies
# 0           ACCESS
# 1    ASSISTANTSHIP
# 2         DELIVERY
# 3       MONITORING
# 4        REPORTING
# ..             ...
# 501      MICROSOFT
# 502            SAS
# 503           SPSS
# 504            SQL
# 505            XML
#
# [506 rows x 7 columns]

# %%
df_technologies.rename(columns={'technologies': 'technology'}, inplace=True)

# %%
# Create a dataframe for locations
df_locations = df.explode('location').reset_index(drop=True)
df_locations
# Out:
#                                               url_link
# 0    https://www.nigeriajob.com/job-vacancies-niger...  \
# 1    https://www.nigeriajob.com/job-vacancies-niger...
# 2    https://www.nigeriajob.com/job-vacancies-niger...
# 3    https://www.nigeriajob.com/job-vacancies-niger...
# 4    https://www.nigeriajob.com/job-vacancies-niger...
# ..                                                 ...
# 393  https://www.nigeriajob.com/job-vacancies-niger...
# 394  https://www.nigeriajob.com/job-vacancies-niger...
# 395  https://www.nigeriajob.com/job-vacancies-niger...
# 396  https://www.nigeriajob.com/job-vacancies-niger...
# 397  https://www.nigeriajob.com/job-vacancies-niger...
#
#                                 job_title company_name
# 0                Examinations Invigilator       VICTVS  \
# 1             Developer ServiceNow (ITSM)  AFRICASHORE
# 2             Developer ServiceNow (ITSM)  AFRICASHORE
# 3             Developer ServiceNow (ITSM)  AFRICASHORE
# 4             Developer ServiceNow (ITSM)  AFRICASHORE
# ..                                    ...          ...
# 393  Data Science Specialist- BMGF (HCD+)          DAI
# 394  Data Science Specialist- BMGF (HCD+)          DAI
# 395  Data Science Specialist- BMGF (HCD+)          DAI
# 396  Data Science Specialist- BMGF (HCD+)          DAI
# 397  Data Science Specialist- BMGF (HCD+)          DAI
#
#                                        job_description  location date_posted
# 0    Job descriptionVICTVS In-Centre Exam Invigilat...     Lagos  2023-04-21  \
# 1    \n\t  We are looking for Developer ServiceNow ...  Abeokuta  2023-04-21
# 2    \n\t  We are looking for Developer ServiceNow ...      Ogun  2023-04-21
# 3    \n\t  We are looking for Developer ServiceNow ...      Abia  2023-04-21
# 4    \n\t  We are looking for Developer ServiceNow ...     Abuja  2023-04-21
# ..                                                 ...       ...         ...
# 393  Background of the projectAfrica (HCD+) is a pl...   Adamawa  2023-03-02
# 394  Background of the projectAfrica (HCD+) is a pl...      Akwa  2023-03-02
# 395  Background of the projectAfrica (HCD+) is a pl...      Ibom  2023-03-02
# 396  Background of the projectAfrica (HCD+) is a pl...   Anambra  2023-03-02
# 397  Background of the projectAfrica (HCD+) is a pl...      -...  2023-03-02
#
#                                           technologies
# 0    [ACCESS, ASSISTANTSHIP, DELIVERY, MONITORING, ...
# 1    [AGILE, AJAX, BOOTSTRAP, CSS, DELTA, EDGE, GEM...
# 2    [AGILE, AJAX, BOOTSTRAP, CSS, DELTA, EDGE, GEM...
# 3    [AGILE, AJAX, BOOTSTRAP, CSS, DELTA, EDGE, GEM...
# 4    [AGILE, AJAX, BOOTSTRAP, CSS, DELTA, EDGE, GEM...
# ..                                                 ...
# 393  [DELTA, ETL, FOUNDATION, HUB, JAVASCRIPT, MICR...
# 394  [DELTA, ETL, FOUNDATION, HUB, JAVASCRIPT, MICR...
# 395  [DELTA, ETL, FOUNDATION, HUB, JAVASCRIPT, MICR...
# 396  [DELTA, ETL, FOUNDATION, HUB, JAVASCRIPT, MICR...
# 397  [DELTA, ETL, FOUNDATION, HUB, JAVASCRIPT, MICR...
#
# [398 rows x 7 columns]

# %%
df_locations.rename(columns={'location': 'location_name'}, inplace=True)

# %%
df_locations=df_locations.drop('technologies',axis=1)
df_technologies=df_technologies.drop('location',axis=1)

# %%
df_final = pd.merge(df_technologies, df_locations, how='inner')
df_final
# Out:
#                                                url_link
# 0     https://www.nigeriajob.com/job-vacancies-niger...  \
# 1     https://www.nigeriajob.com/job-vacancies-niger...
# 2     https://www.nigeriajob.com/job-vacancies-niger...
# 3     https://www.nigeriajob.com/job-vacancies-niger...
# 4     https://www.nigeriajob.com/job-vacancies-niger...
# ...                                                 ...
# 4485  https://www.nigeriajob.com/job-vacancies-niger...
# 4486  https://www.nigeriajob.com/job-vacancies-niger...
# 4487  https://www.nigeriajob.com/job-vacancies-niger...
# 4488  https://www.nigeriajob.com/job-vacancies-niger...
# 4489  https://www.nigeriajob.com/job-vacancies-niger...
#
#                                  job_title company_name
# 0                 Examinations Invigilator       VICTVS  \
# 1                 Examinations Invigilator       VICTVS
# 2                 Examinations Invigilator       VICTVS
# 3                 Examinations Invigilator       VICTVS
# 4                 Examinations Invigilator       VICTVS
# ...                                    ...          ...
# 4485  Data Science Specialist- BMGF (HCD+)          DAI
# 4486  Data Science Specialist- BMGF (HCD+)          DAI
# 4487  Data Science Specialist- BMGF (HCD+)          DAI
# 4488  Data Science Specialist- BMGF (HCD+)          DAI
# 4489  Data Science Specialist- BMGF (HCD+)          DAI
#
#                                         job_description date_posted
# 0     Job descriptionVICTVS In-Centre Exam Invigilat...  2023-04-21  \
# 1     Job descriptionVICTVS In-Centre Exam Invigilat...  2023-04-21
# 2     Job descriptionVICTVS In-Centre Exam Invigilat...  2023-04-21
# 3     Job descriptionVICTVS In-Centre Exam Invigilat...  2023-04-21
# 4     Job descriptionVICTVS In-Centre Exam Invigilat...  2023-04-21
# ...                                                 ...         ...
# 4485  Background of the projectAfrica (HCD+) is a pl...  2023-03-02
# 4486  Background of the projectAfrica (HCD+) is a pl...  2023-03-02
# 4487  Background of the projectAfrica (HCD+) is a pl...  2023-03-02
# 4488  Background of the projectAfrica (HCD+) is a pl...  2023-03-02
# 4489  Background of the projectAfrica (HCD+) is a pl...  2023-03-02
#
#          technology location_name
# 0            ACCESS         Lagos
# 1     ASSISTANTSHIP         Lagos
# 2          DELIVERY         Lagos
# 3        MONITORING         Lagos
# 4         REPORTING         Lagos
# ...             ...           ...
# 4485            XML       Adamawa
# 4486            XML          Akwa
# 4487            XML          Ibom
# 4488            XML       Anambra
# 4489            XML          -...
#
# [4490 rows x 7 columns]

# %%
df_final.rename(columns={'row_num': 'id'}, inplace=True)

# %%
df_final
# Out:
#                                                url_link
# 0     https://www.nigeriajob.com/job-vacancies-niger...  \
# 1     https://www.nigeriajob.com/job-vacancies-niger...
# 2     https://www.nigeriajob.com/job-vacancies-niger...
# 3     https://www.nigeriajob.com/job-vacancies-niger...
# 4     https://www.nigeriajob.com/job-vacancies-niger...
# ...                                                 ...
# 4485  https://www.nigeriajob.com/job-vacancies-niger...
# 4486  https://www.nigeriajob.com/job-vacancies-niger...
# 4487  https://www.nigeriajob.com/job-vacancies-niger...
# 4488  https://www.nigeriajob.com/job-vacancies-niger...
# 4489  https://www.nigeriajob.com/job-vacancies-niger...
#
#                                  job_title company_name
# 0                 Examinations Invigilator       VICTVS  \
# 1                 Examinations Invigilator       VICTVS
# 2                 Examinations Invigilator       VICTVS
# 3                 Examinations Invigilator       VICTVS
# 4                 Examinations Invigilator       VICTVS
# ...                                    ...          ...
# 4485  Data Science Specialist- BMGF (HCD+)          DAI
# 4486  Data Science Specialist- BMGF (HCD+)          DAI
# 4487  Data Science Specialist- BMGF (HCD+)          DAI
# 4488  Data Science Specialist- BMGF (HCD+)          DAI
# 4489  Data Science Specialist- BMGF (HCD+)          DAI
#
#                                         job_description date_posted
# 0     Job descriptionVICTVS In-Centre Exam Invigilat...  2023-04-21  \
# 1     Job descriptionVICTVS In-Centre Exam Invigilat...  2023-04-21
# 2     Job descriptionVICTVS In-Centre Exam Invigilat...  2023-04-21
# 3     Job descriptionVICTVS In-Centre Exam Invigilat...  2023-04-21
# 4     Job descriptionVICTVS In-Centre Exam Invigilat...  2023-04-21
# ...                                                 ...         ...
# 4485  Background of the projectAfrica (HCD+) is a pl...  2023-03-02
# 4486  Background of the projectAfrica (HCD+) is a pl...  2023-03-02
# 4487  Background of the projectAfrica (HCD+) is a pl...  2023-03-02
# 4488  Background of the projectAfrica (HCD+) is a pl...  2023-03-02
# 4489  Background of the projectAfrica (HCD+) is a pl...  2023-03-02
#
#          technology location_name
# 0            ACCESS         Lagos
# 1     ASSISTANTSHIP         Lagos
# 2          DELIVERY         Lagos
# 3        MONITORING         Lagos
# 4         REPORTING         Lagos
# ...             ...           ...
# 4485            XML       Adamawa
# 4486            XML          Akwa
# 4487            XML          Ibom
# 4488            XML       Anambra
# 4489            XML          -...
#
# [4490 rows x 7 columns]

# %%
# !pip install sqlalchemy ipython-sql
# Out:
# Requirement already satisfied: sqlalchemy in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (2.0.9)
# Requirement already satisfied: ipython-sql in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (0.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from sqlalchemy) (2.0.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from sqlalchemy) (4.5.0)
# Requirement already satisfied: ipython-genutils in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: six in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from ipython-sql) (8.12.0)
# Requirement already satisfied: sqlparse in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from ipython-sql) (0.4.4)
# Requirement already satisfied: prettytable in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from ipython-sql) (3.7.0)
# Requirement already satisfied: stack-data in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from ipython->ipython-sql) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from ipython->ipython-sql) (5.9.0)
# Requirement already satisfied: decorator in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from ipython->ipython-sql) (2.14.0)
# Requirement already satisfied: backcall in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: jedi>=0.16 in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from ipython->ipython-sql) (0.18.2)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from ipython->ipython-sql) (3.0.38)
# Requirement already satisfied: appnope in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from ipython->ipython-sql) (0.1.3)
# Requirement already satisfied: pexpect>4.3 in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from ipython->ipython-sql) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: wcwidth in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from prettytable->ipython-sql) (0.2.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: pure-eval in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from stack-data->ipython->ipython-sql) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/ctoanadu/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from stack-data->ipython->ipython-sql) (2.2.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: pip install --upgrade pip

# %%
# %reload_ext sql
# %sql postgresql://postgres:Password1@localhost:5432/beekin_db

# %%
# %sql select distinct job_title from beekin_job
# Out:
#  * postgresql://postgres:***@localhost:5432/beekin_db
# 46 rows affected.
# [('Z/OS System Engineer Senior Storage(M/F)',),
#  ('IT Support & Network Analyst/Specialist - Osogbo',),
#  ('JAVA Developer (M/F)',),
#  ('AWS Solutions Architect (M/F)',),
#  ('OBJECTIVE-C Developer (M/F)',),
#  ('GENESYS Architect (M/F)',),
#  ('PHP Developer (M/F)',),
#  ('Senior Electrical Engineer',),
#  ('Test Automation Engineer (M/F)',),
#  ('NODE.JS Developer (M/F)',),
#  ('DOTNET Developer (M/F)',),
#  ('QA Tester (M/F)',),
#  ('LARAVEL Developer (M/F)',),
#  ('Cloud Computing and Virtualization Engineer (M/F)',),
#  ('JAVASCRIPT Developer (M/F)',),
#  ('Data Science Specialist- BMGF (HCD+)',),
#  ('Head of IT',),
#  ('DBA IMS/DB2 Z/OS(M/F)',),
#  ('ANGULAR Developer (M/F)',),
#  ('AWS Cloud Architect (M/F)',),
#  ('DevOps Engineer (M/F)',),
#  ('Cloud System Administrator (M/F)',),
#  ('Network Support Engineer',),
#  ('Cloud Microservices Architect (M/F)',),
#  ('Examinations Invigilator',),
#  ('Test and Validation Engineer (M/F)',),
#  ('PYTHON Developer (M/F)',),
#  ('Cyber Security Engineer (M/F)',),
#  ('Cloud System Integrator (M/F)',),
#  ('Instrumentation Technician',),
#  ('JAVA JEE Developer (M/F)',),
#  ('DATASTAGE Architect (M/F)',),
#  ('Middleware System Engineer Z/OS (M/F)',),
#  ('SWIFT Developer (M/F)',),
#  ('REACT Developer (M/F)',),
#  ('IOS Developer (M/F)',),
#  ('RUBY ON RAILS Developer (M/F)',),
#  ('Cloud Architect (M/F)',),
#  ('UX / UI Designer (M/F)',),
#  ('Network Architect (M/F)',),
#  ('Industrial Training Internship',),
#  ('AZURE Solutions Architect (M/F)',),
#  ('KOTLIN Developer (M/F)',),
#  ('Developer ServiceNow (ITSM)',),
#  ('I.T Service Manager',),
#  ('Cloud Engineer (M/F)',)]
